# %%
import FinalRFmodel
import FileProcessing
import warnings
warnings.filterwarnings("ignore")

# %%
model = FinalRFmodel.ModelClass()                 
fileProcessing=FileProcessing.FileProcessing()

# %%
file_name='Cleaned_NGSIM_Data3'
ngsim1=fileProcessing.read_input(file_name)
# Out:
# original File path: c:\Users\neels\Desktop\Capstone\carfollowing\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Data File path: c:\Users\neels\Desktop\Capstone\carfollowing\DataDrivenCarFollowing\datadrivencarfollowing-v1\data

# %%
ngsim = model.preprocessing(ngsim1,0.4)
train_pair = model.select_training_pairs(ngsim)
train,test = model.split_df_into_train_test(ngsim,train_pair)
X_train, y_train, X_test, y_test,rf = model.fit_rfmodel(train,test,150)
p= model.prediction_test_pairs(test,0,6)
print(p)
F = model.prediction(test,p,'nextframeAcc',rf,0.4)
# Out:
# ['1978-1984', '1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419']

# %%
F = model.prediction(test,['1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419'],'nextframeAcc',rf,0.4)

# %%
F
# Out:
#         Vehicle_ID  Frame_ID    Global_Time  Local_X   Local_Y     Global_X  \
# 866           1996      5719  1118847550800   53.021    40.078  6451113.589
# 870           1996      5720  1118847550900   53.001    44.078  6451116.277
# 874           1996      5721  1118847551000   52.979    48.078  6451118.966
# 883           1996      5722  1118847551100   52.959    52.077  6451121.654
# 885           1996      5723  1118847551200   52.941    55.578  6451124.007
# ...            ...       ...            ...      ...       ...          ...
# 152549        1996      7995  1118848641500   53.870  1655.955  6452282.481
# 152564        1996      7996  1118848641600   53.873  1660.122  6452285.629
# 152574        1996      7997  1118848641700   53.876  1664.306  6452288.786
# 152581        1996      7998  1118848641800   53.879  1668.490  6452291.943
# 152588        1996      7999  1118848641900   53.881  1672.656  6452295.091
#
#            Global_Y  v_length  v_Class      v_Vel  ...  nextframeAcc  \
# 866     1873317.038    5.1816        2  10.750296  ...      0.000000
# 870     1873314.076    5.1816        2  10.750296  ...     -1.469136
# 874     1873311.115    5.1816        2  10.750296  ...     -0.079248
# 883     1873308.153    5.1816        2  10.750296  ...      0.070104
# 885     1873305.561    5.1816        2  10.750296  ...      0.082296
# ...             ...       ...      ...        ...  ...           ...
# 152549  1872252.067    4.4196        2  12.588240  ...     -1.292352
# 152564  1872249.334    4.4196        2  12.682728  ...     -1.658112
# 152574  1872246.594    4.4196        2  12.713208  ...      1.008888
# 152581  1872243.854    4.4196        2  12.682728  ...      3.413760
# 152588  1872241.122    4.4196        2  12.585192  ...      2.078736
#
#         nextframesvel  nextframeposition  nextframespacing  \
# 866         10.750296             55.578          9.518904
# 870         10.750296             59.119          9.393936
# 874         10.658856             62.587          9.265920
# 883         10.655808             66.079          9.113520
# 885         10.661904             69.575          8.958072
# ...               ...                ...               ...
# 152549      12.585192           1672.656         44.250864
# 152564      12.444984           1676.773         44.415456
# 152574      12.451080           1680.771         44.647104
# 152581      12.688824           1684.835         44.860464
# 152588      12.889992           1689.071         44.997624
#
#         Pair_Time_Duration PrecVehType Vehicle.type      pacc       pvel  \
# 866                    0.1           2            2 -1.469136  10.750296
# 870                    0.2           2            2  0.164287  10.162642
# 874                    0.3           2            2 -0.730016  10.228356
# 883                    0.4           2            2 -0.785510   9.936350
# 885                    0.5           2            2  0.040782   9.622146
# ...                    ...         ...          ...       ...        ...
# 152549                95.4           2            2  0.428000  13.168008
# 152564                95.5           2            2  0.131288  13.339208
# 152574                95.6           2            2 -0.164592  13.391723
# 152581                95.7           2            2 -0.116312  13.325886
# 152588                95.8           2            2 -0.293624  13.279361
#
#            pspacing
# 866       10.594848
# 870      -48.756388
# 874      -52.834587
# 883      -56.867528
# 885      -60.779228
# ...             ...
# 152549 -3496.870340
# 152564 -3502.171783
# 152574 -3507.517969
# 152581 -3512.861490
# 152588 -3518.182540
#
# [958 rows x 44 columns]

# %%
F1 = F[F["L-F_Pair"] == '1987-1996']
model.plot_1(F1,'nextframeAcc','pacc','Acceleration of Actual vs Fitted values using reaction_time 0.1sec')
model.plot_1(F1,'nextframesvel','pvel', 'Velocity of Actual vs Fitted values using reaction_time 0.1sec')
model.plot_1(F1,'nextframespacing','pspacing', 'Velocity of Actual vs Fitted values using reaction_time 0.1sec')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\neels\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ngsim = model.preprocessing(ngsim1,0.4)
train_pair = model.select_training_pairs(ngsim)
train,test = model.split_df_into_train_test(ngsim,train_pair)
X_train, y_train, X_test, y_test,rf = model.fit_rfmodel(train,test,150)
p= model.prediction_test_pairs(test,0,6)
print(p)
F = model.prediction(test,p,'nextframeAcc',rf,0.4)
# Out:
# ['1978-1984', '1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419']

# %%
F1 = F[F["L-F_Pair"] == "1978-1984"]
model.plot_1(F1,'nextframeAcc','pacc','Acceleration of Actual vs Fitted values using reaction_time 0.4sec')
model.plot_1(F1,'nextframesvel','pvel', 'Velocity of Actual vs Fitted values using reaction_time 0.4sec')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\neels\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ngsim = model.preprocessing(ngsim1,0.5)
train_pair = model.select_training_pairs(ngsim)
train,test = model.split_df_into_train_test(ngsim,train_pair)
X_train, y_train, X_test, y_test,rf = model.fit_rfmodel(train,test,150)
p= model.prediction_test_pairs(test,0,6)
print(p)
F = model.prediction(test,p,'nextframeAcc',rf,0.5)
# Out:
# ['1978-1984', '1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419']

# %%
F1 = F[F["L-F_Pair"] == "1978-1984"]
model.plot_1(F1,'nextframeAcc','pacc','Acceleration of Actual vs Fitted values using reaction_time 0.5sec')
model.plot_1(F1,'nextframesvel','pvel', 'Velocity of Actual vs Fitted values using reaction_time 0.5sec')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\neels\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ngsim = model.preprocessing(ngsim1,0.8)
train_pair = model.select_training_pairs(ngsim)
train,test = model.split_df_into_train_test(ngsim,train_pair)
X_train, y_train, X_test, y_test,rf = model.fit_rfmodel(train,test,150)
p= model.prediction_test_pairs(test,0,6)
print(p)
F = model.prediction(test,p,'nextframeAcc',rf,0.8)
# Out:
# ['1978-1984', '1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419']

# %%
F1 = F[F["L-F_Pair"] == "1978-1984"]
model.plot_1(F1,'nextframeAcc','pacc','Acceleration of Actual vs Fitted values using reaction_time 0.8sec')
model.plot_1(F1,'nextframesvel','pvel', 'Velocity of Actual vs Fitted values using reaction_time 0.8sec')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\neels\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ngsim = model.preprocessing(ngsim1,1)
train_pair = model.select_training_pairs(ngsim)
train,test = model.split_df_into_train_test(ngsim,train_pair)
X_train, y_train, X_test, y_test,rf = model.fit_rfmodel(train,test,150)
p= model.prediction_test_pairs(test,0,6)
print(p)
F = model.prediction(test,p,'nextframeAcc',rf,1)
# Out:
# ['1978-1984', '1987-1996', '2162-2170', '2190-2200', '2194-2207', '2399-2419']

# %%
F1 = F[F["L-F_Pair"] == "1978-1984"]
model.plot_1(F1,'nextframeAcc','pacc','Acceleration of Actual vs Fitted values using reaction_time 1sec')
model.plot_1(F1,'nextframesvel','pvel', 'Velocity of Actual vs Fitted values using reaction_time 1sec')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\neels\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
