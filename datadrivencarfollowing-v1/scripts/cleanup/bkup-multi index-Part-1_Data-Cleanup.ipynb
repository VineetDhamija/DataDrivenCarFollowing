# %%
import numpy as np 
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

from millify import millify

# %%
from pathlib import Path
p = Path().cwd()
print(f"original File path: {p}")
stringpath= str(p)[0:str(p).rfind('\\')] + '\\data'
print(f"Updated File Path to pick from Data Library: { stringpath}")
ngsimfile=stringpath + '/' + 'Next_Generation_Simulation__NGSIM__Vehicle_Trajectories_and_Supporting_Data.csv'
ngsim = pd.read_csv(ngsimfile,low_memory=False)
print(f"{ngsim.duplicated().sum()} duplicate values have been removed")
ngsim.drop_duplicates(inplace=True)
# Out:
# original File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Updated File Path to pick from Data Library: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data
# 704000 duplicate values have been removed

# %%
ngsim['v_length']= ngsim['v_length']*0.3048
ngsim['Space_Headway']= ngsim['Space_Headway']*0.3048
ngsim['v_Vel']= ngsim['v_Vel']*0.3048
ngsim['v_Acc']= ngsim['v_Acc']*0.3048
ngsim['Relative_Time']= ngsim['Global_Time'] - ngsim['Global_Time'].min() + 1
ngsim= ngsim.drop(columns=['Movement', 'Direction','Section_ID','Int_ID','D_Zone','O_Zone','Lane_ID','Following','v_Width','Total_Frames','Frame_ID'])

# %%
#filtered_ngsim= ngsim[((ngsim['Location'] == 'us-101') | (ngsim['Location'] == 'i-80')) & (ngsim['Preceding']>0) & (ngsim['Following']>0) ]
ngsim['Preceding_Vehicle_Class'] = np.NaN
ngsim['Rear_to_Front_Space_Headway'] = np.NaN
ngsim['Follower_Minus_Preceding_Velocity_diff'] = np.NaN

ngsim["v_Class_Name"] = ngsim["v_Class"].map({1:"Motorcycle", 2: "Car", 3: "Heavy Vehicle"})

filtered_ngsim_U= ngsim[((ngsim['Location'] == 'us-101')) & ((ngsim['Vehicle_ID'] <= 1000 )  )]
#These two vehicles have a bad trajectory and keep on following each other in a single lane in a matter of 
filtered_ngsim_I= ngsim[(ngsim['Location'] == 'i-80') & ( ((ngsim['Vehicle_ID'] != 1748 )  & (ngsim['Preceding'] != 1734 )) &(  (ngsim['Vehicle_ID'] != 1734 )  & (ngsim['Preceding'] != 1748 )))& ((ngsim['Vehicle_ID'] <= 1000 )  )]
#filtered_ngsim_I= ngsim[(ngsim['Location'] == 'i-80')]

# %%
filtered_ngsim_U.set_index(['Vehicle_ID', 'Preceding','Relative_Time'], append=True,inplace=True)
print(filtered_ngsim_U.index.is_monotonic_increasing)
filtered_ngsim_U=filtered_ngsim_U.sort_index()
print(filtered_ngsim_U.index.is_monotonic_increasing)
# Out:
# True
# True

# %%
filtered_ngsim_U[((filtered_ngsim_U['Space_Headway'] == 0 ) & (filtered_ngsim_U.index.get_level_values("Preceding") > 0 )) ]
# Out:
#                                              Global_Time  Local_X   Local_Y  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401  1118847948500   12.942  1420.624
# 107058 806        814       1117685210701  1118848229800    6.699   796.216
# 452347 366        370       1117685952801  1118848971900   12.613   835.132
#
#                                               Global_X     Global_Y  v_length  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401  6452132.084  1872437.889    2.5908
# 107058 806        814       1117685210701  6451666.005  1872853.511    4.4196
# 452347 366        370       1117685952801  6451695.487  1872819.732    2.1336
#
#                                            v_Class      v_Vel     v_Acc  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401        1  17.373600 -0.064008
# 107058 806        814       1117685210701        2   2.795016  0.000000
# 452347 366        370       1117685952801        1   8.695944  1.816608
#
#                                            Space_Headway  Time_Headway  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401            0.0           0.0
# 107058 806        814       1117685210701            0.0           0.0
# 452347 366        370       1117685952801            0.0           0.0
#
#                                           Location  Preceding_Vehicle_Class  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401   us-101                      NaN
# 107058 806        814       1117685210701   us-101                      NaN
# 452347 366        370       1117685952801   us-101                      NaN
#
#                                            Rear_to_Front_Space_Headway  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401                          NaN
# 107058 806        814       1117685210701                          NaN
# 452347 366        370       1117685952801                          NaN
#
#                                            Follower_Minus_Preceding_Velocity_diff  \
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401                                     NaN
# 107058 806        814       1117685210701                                     NaN
# 452347 366        370       1117685952801                                     NaN
#
#                                           v_Class_Name
#        Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401   Motorcycle
# 107058 806        814       1117685210701          Car
# 452347 366        370       1117685952801   Motorcycle

# %%
filtered_ngsim_I[((filtered_ngsim_I['Space_Headway'] == 0 ) & (filtered_ngsim_I['Preceding'] > 0 )) ]
# Out:
#          Vehicle_ID    Global_Time  Local_X   Local_Y     Global_X  \
# 9365776         572  1113437894100   17.928  1485.487  6042644.407
#
#             Global_Y  v_length  v_Class  v_Vel  v_Acc  Preceding  \
# 9365776  2134541.664   4.35864        2    0.0    0.0        566
#
#          Space_Headway  Time_Headway Location  Relative_Time  \
# 9365776            0.0       9999.99     i-80  1112274875001
#
#          Preceding_Vehicle_Class  Rear_to_Front_Space_Headway  \
# 9365776                      NaN                          NaN
#
#          Follower_Minus_Preceding_Velocity_diff v_Class_Name
# 9365776                                     NaN          Car

# %%
#filtered_vClass_U= filtered_ngsim_U[['Vehicle_ID','v_Class','v_length']].drop_duplicates().sort_values('v_Class')
filtered_vClass_U= filtered_ngsim_U.groupby(['Vehicle_ID','v_Class'], as_index=False)['v_length'].mean().sort_values('v_Class')
v_Class_M_U     =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 1 )  ]['Vehicle_ID'])
v_Class_C_U     =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 2 )  ]['Vehicle_ID'])
v_Class_HV_U    =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 3 )  ]['Vehicle_ID'])

#df.groupby(["state", "gender"])["last_name"].count()

#filtered_vClass_I= filtered_ngsim_I[['Vehicle_ID','v_Class','v_length']].drop_duplicates().sort_values('v_Class')
filtered_vClass_I = filtered_ngsim_I.groupby(['Vehicle_ID','v_Class'], as_index=False)['v_length'].mean().sort_values('v_Class')
v_Class_M_I     =set(filtered_vClass_I[(filtered_vClass_I['v_Class'] == 1 )  ]['Vehicle_ID'])
v_Class_C_I     =set(filtered_vClass_I[(filtered_vClass_I['v_Class'] == 2 )  ]['Vehicle_ID'])
v_Class_HV_I    =set(filtered_vClass_I[(filtered_vClass_I['v_Class'] == 3 )  ]['Vehicle_ID'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vehicle_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts\Part-1_Data-Cleanup.ipynb Cell 8' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000006?line=0'>1</a> #filtered_vClass_U= filtered_ngsim_U[['Vehicle_ID','v_Class','v_length']].drop_duplicates().sort_values('v_Class')
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000006?line=1'>2</a> filtered_vClass_U= filtered_ngsim_U.groupby(['Vehicle_ID','v_Class'], as_index=False)['v_length'].mean().sort_values('v_Class')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000006?line=2'>3</a> v_Class_M_U     =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 1 )  ]['Vehicle_ID'])
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000006?line=3'>4</a> v_Class_C_U     =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 2 )  ]['Vehicle_ID'])
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000006?line=4'>5</a> v_Class_HV_U    =set(filtered_vClass_U[(filtered_vClass_U['v_Class'] == 3 )  ]['Vehicle_ID'])
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Vehicle_ID'

# %%
filtered_ngsim_U.index
# Out:
# MultiIndex([(      0, 515, 500, 1117685055901),
#             (      7, 744, 740, 1117685162101),
#             (     15, 496, 510, 1117685099501),
#             (     17, 946, 936, 1117685233301),
#             (     28,   5,   0, 1117684841001),
#             (     36, 686, 680, 1117685181701),
#             (     39, 709,   0, 1117685215701),
#             (     43, 485, 479, 1117686004401),
#             (     44, 182, 170, 1117684040101),
#             (     48, 143, 135, 1117684939401),
#             ...
#             (8704767, 406, 401, 1117685912901),
#             (8704772, 711, 704, 1117685139001),
#             (8704774, 447, 442, 1117686020201),
#             (8704777, 375, 384, 1117685985801),
#             (8704781, 427, 422, 1117684064001),
#             (8704785, 582, 561, 1117684102401),
#             (8704787, 690, 680, 1117684133501),
#             (8704790, 347, 338, 1117685038201),
#             (8704793, 448, 445, 1117685991101),
#             (8704797, 601, 593, 1117684146901)],
#            names=[None, 'Vehicle_ID', 'Preceding', 'Relative_Time'], length=1645876)

# %%
filtered_ngsim_U.index.rename(['id', 'Vehicle_ID', 'Preceding', 'Relative_Time'], inplace=True)

# %%
filtered_ngsim_U.xs((500,515),level=("Preceding",'Vehicle_ID'))
# Out:
#                          Global_Time  Local_X   Local_Y     Global_X  \
#         Relative_Time
# 0       1117685055901  1118848075000   30.034   188.062  6451203.729
# 1098    1117685056001  1118848075100   30.063   190.410  6451205.318
# 9508    1117685060201  1118848079300   28.549   281.971  6451270.837
# 42453   1117685105001  1118848124100   29.607  1082.700  6451866.567
# 52236   1117685099401  1118848118500   29.868  1015.798  6451815.977
# ...                              ...      ...       ...          ...
# 8665083 1117685078501  1118848097600   28.976   782.361  6451640.883
# 8669638 1117685071601  1118848090700   30.432   576.420  6451485.551
# 8672041 1117685104701  1118848123800   29.649  1078.958  6451863.748
# 8681184 1117685114901  1118848134000   30.825  1293.930  6452024.815
# 8692685 1117685111101  1118848130200   30.332  1198.451  6451953.369
#
#                           Global_Y  v_length  v_Class     v_Vel     v_Acc  \
#         Relative_Time
# 0       1117685055901  1873252.549    3.9624        2  7.104888  0.624840
# 1098    1117685056001  1873250.798    3.9624        2  7.150608  0.277368
# 9508    1117685060201  1873184.648    3.9624        2  6.065520 -1.286256
# 42453   1117685105001  1872647.592    3.9624        2  4.303776  3.413760
# 52236   1117685099401  1872691.287    3.9624        2  3.526536  1.228344
# ...                            ...       ...      ...       ...       ...
# 8665083 1117685078501  1872845.922    3.9624        2  8.842248  2.368296
# 8669638 1117685071601  1872981.540    3.9624        2  9.238488  0.835152
# 8672041 1117685104701  1872649.992    3.9624        2  3.605784  0.566928
# 8681184 1117685114901  1872507.772    3.9624        2  8.823960  0.502920
# 8692685 1117685111101  1872571.014    3.9624        2  7.266432  1.481328
#
#                        Space_Headway  Time_Headway Location  \
#         Relative_Time
# 0       1117685055901      36.301680          5.11   us-101
# 1098    1117685056001      36.463224          5.10   us-101
# 9508    1117685060201      44.772072          7.38   us-101
# 42453   1117685105001      29.303472          6.81   us-101
# 52236   1117685099401      26.956512          7.64   us-101
# ...                              ...           ...      ...
# 8665083 1117685078501      38.770560          4.38   us-101
# 8669638 1117685071601      55.604664          6.02   us-101
# 8672041 1117685104701      29.004768          8.04   us-101
# 8681184 1117685114901      33.427416          3.79   us-101
# 8692685 1117685111101      31.555944          4.34   us-101
#
#                        Preceding_Vehicle_Class  Rear_to_Front_Space_Headway  \
#         Relative_Time
# 0       1117685055901                      NaN                          NaN
# 1098    1117685056001                      NaN                          NaN
# 9508    1117685060201                      NaN                          NaN
# 42453   1117685105001                      NaN                          NaN
# 52236   1117685099401                      NaN                          NaN
# ...                                        ...                          ...
# 8665083 1117685078501                      NaN                          NaN
# 8669638 1117685071601                      NaN                          NaN
# 8672041 1117685104701                      NaN                          NaN
# 8681184 1117685114901                      NaN                          NaN
# 8692685 1117685111101                      NaN                          NaN
#
#                        Follower_Minus_Preceding_Velocity_diff v_Class_Name
#         Relative_Time
# 0       1117685055901                                     NaN          Car
# 1098    1117685056001                                     NaN          Car
# 9508    1117685060201                                     NaN          Car
# 42453   1117685105001                                     NaN          Car
# 52236   1117685099401                                     NaN          Car
# ...                                                       ...          ...
# 8665083 1117685078501                                     NaN          Car
# 8669638 1117685071601                                     NaN          Car
# 8672041 1117685104701                                     NaN          Car
# 8681184 1117685114901                                     NaN          Car
# 8692685 1117685111101                                     NaN          Car
#
# [673 rows x 16 columns]

# %%
filtered_ngsim_U['id'][filtered_ngsim_U.xs((0),level=("id"))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts\Part-1_Data-Cleanup.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000037?line=0'>1</a> filtered_ngsim_U['id'][filtered_ngsim_U.xs((0),level=("id"))]
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
filtered_ngsim_U.index
# Out:
# MultiIndex([(      0, 515, 500, 1117685055901),
#             (      7, 744, 740, 1117685162101),
#             (     15, 496, 510, 1117685099501),
#             (     17, 946, 936, 1117685233301),
#             (     28,   5,   0, 1117684841001),
#             (     36, 686, 680, 1117685181701),
#             (     39, 709,   0, 1117685215701),
#             (     43, 485, 479, 1117686004401),
#             (     44, 182, 170, 1117684040101),
#             (     48, 143, 135, 1117684939401),
#             ...
#             (8704767, 406, 401, 1117685912901),
#             (8704772, 711, 704, 1117685139001),
#             (8704774, 447, 442, 1117686020201),
#             (8704777, 375, 384, 1117685985801),
#             (8704781, 427, 422, 1117684064001),
#             (8704785, 582, 561, 1117684102401),
#             (8704787, 690, 680, 1117684133501),
#             (8704790, 347, 338, 1117685038201),
#             (8704793, 448, 445, 1117685991101),
#             (8704797, 601, 593, 1117684146901)],
#            names=[None, 'Vehicle_ID', 'Preceding', 'Relative_Time'], length=1645876)

# %%
#filtered_ngsim_U.index.get_level_values("") == 
filtered_ngsim_U['v_Vel'][filtered_ngsim_U.index.get_level_values("Vehicle_ID") == 500 ]
# Out:
# id       Vehicle_ID  Preceding  Relative_Time
# 10727    500         495        1117685085401     1.524000
# 16529    500         488        1117684117901    17.416272
# 17344    500         488        1117684112301    17.644872
# 21393    500         495        1117685073301     7.620000
# 31466    500         0          1117686016301    16.754856
#                                                    ...
# 8676583  500         495        1117685141501     4.367784
# 8683708  500         0          1117686046501     4.590288
# 8686647  500         495        1117685143701     5.370576
# 8695071  500         0          1117685151301     6.553200
# 8702978  500         494        1117686028001    14.249400
# Name: v_Vel, Length: 1923, dtype: float64

# %%
result = []
velocity_diff=[]
space_headway_rear_to_front = []

for i in filtered_ngsim_U.index.get_level_values(0):
    print(i)
    if i%500000==0:
        print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")
    #this row below is time taking

    #velocity = filtered_ngsim_U['v_Vel'][( filtered_ngsim_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i] ) & (filtered_ngsim_U['Relative_Time']== filtered_ngsim_U['Relative_Time'][i]) ] - filtered_ngsim_U['v_Vel'][i]
    velocity = filtered_ngsim_U['v_Vel'][( filtered_ngsim_U.index.get_level_values("Vehicle_ID")== filtered_ngsim_U.index.get_level_values(i,"Preceding") ) & (filtered_ngsim_U.index.get_level_values("Relative_Time")== filtered_ngsim_U.index.get_level_values(i,"Relative_Time") ) ] - filtered_ngsim_U['v_Vel'][i]
    #this row above is time taking
    #space = filtered_ngsim_U['Space_Headway'][i]  - filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i]]
     #print(f"i:{i,} space: {space}, filtered_ngsim_U['Space_Headway'][i]: {filtered_ngsim_U['Space_Headway'][i]},relative time={filtered_ngsim_U['Relative_Time'][i]},preceding vehicle:{filtered_ngsim_U['Preceding'][i]}   minus :{filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i]].mean()} ")
    space_headway_rear_to_front.append(space)
    velocity_diff.append(velocity)
    
    if filtered_ngsim_U['Preceding'][i] in v_Class_C_U:
        result.append('Car')
    elif filtered_ngsim_U['Preceding'][i] in v_Class_HV_U:
        result.append('Heavy Vehicle')
    elif filtered_ngsim_U['Preceding'][i] in v_Class_M_U:
        result.append('Motorcycle')
    else: 
        result.append(np.NaN)

filtered_ngsim_U['Preceding_Vehicle_Class'] = result
filtered_ngsim_U['Follower_Minus_Preceding_Velocity_diff'] = velocity_diff
filtered_ngsim_U['Rear_to_Front_Space_Headway'] = space_headway_rear_to_front
# Out:
# 0
# row count0.00 processed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts\Part-1_Data-Cleanup.ipynb Cell 11' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=7'>8</a>     print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=8'>9</a> #this row below is time taking
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=9'>10</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=10'>11</a> #velocity = filtered_ngsim_U['v_Vel'][( filtered_ngsim_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i] ) & (filtered_ngsim_U['Relative_Time']== filtered_ngsim_U['Relative_Time'][i]) ] - filtered_ngsim_U['v_Vel'][i]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=11'>12</a> velocity = filtered_ngsim_U['v_Vel'][( filtered_ngsim_U.index.get_level_values("Vehicle_ID")== filtered_ngsim_U.index.get_level_values(i,"Preceding") ) & (filtered_ngsim_U.index.get_level_values("Relative_Time")== filtered_ngsim_U.index.get_level_values(i,"Relative_Time") ) ] - filtered_ngsim_U['v_Vel'][i]
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=12'>13</a> #this row above is time taking
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=13'>14</a> #space = filtered_ngsim_U['Space_Headway'][i]  - filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i]]
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=14'>15</a>  #print(f"i:{i,} space: {space}, filtered_ngsim_U['Space_Headway'][i]: {filtered_ngsim_U['Space_Headway'][i]},relative time={filtered_ngsim_U['Relative_Time'][i]},preceding vehicle:{filtered_ngsim_U['Preceding'][i]}   minus :{filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i]].mean()} ")
#      <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000007?line=15'>16</a> space_headway_rear_to_front.append(space)
#
# TypeError: get_level_values() takes 2 positional arguments but 3 were given

# %%
'''rEMOVE THIS AFTER VALIDATING THE US-101 FILE 
result = []
space_headway_rear_to_front = []

for i in filtered_ngsim_I.index:
    if filtered_ngsim_I['Preceding'][i] in v_Class_C_I:
        result.append('Car')
    elif filtered_ngsim_I['Preceding'][i] in v_Class_HV_I:
        result.append('Heavy Vehicle')
    elif filtered_ngsim_I['Preceding'][i] in v_Class_M_I:
        result.append('Motorcycle')
    else: 
        result.append(np.NaN)
    velocity = filtered_ngsim_I['v_Vel'][( filtered_ngsim_I['Vehicle_ID']== filtered_ngsim_I['Preceding'][i] ) & (filtered_ngsim_I['Relative_Time']== filtered_ngsim_I['Relative_Time'][i]) ] - filtered_ngsim_I['v_Vel'][i]
    space=filtered_ngsim_I['Space_Headway'][i]  - filtered_vClass_I['v_length'][filtered_vClass_I['Vehicle_ID']== filtered_ngsim_I['Preceding'][i]]
    velocity_diff.append(velocity)
    space_headway_rear_to_front.append(space)
    if i%500000==0:
        print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")

filtered_ngsim_I['Rear_to_Front_Space_Headway'] = space_headway_rear_to_front
filtered_ngsim_I['Follower_Minus_Preceding_Velocity_diff'] = velocity_diff
filtered_ngsim_I['Preceding_Vehicle_Class'] = result
'''

# %%
'''
space_headway_rear_to_front = []

for i in filtered_ngsim_I.index:
    space=filtered_ngsim_I['Space_Headway'][i]  - filtered_vClass_I['v_length'][filtered_vClass_I['Vehicle_ID']== filtered_ngsim_I['Preceding'][i]].mean()
    space_headway_rear_to_front.append(space)
    if i%500000==0:
        print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")
filtered_ngsim_I['Rear_to_Front_Space_Headway'] = space_headway_rear_to_front
'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts\Part-1_Data-Cleanup.ipynb Cell 9' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000008?line=0'>1</a> space_headway_rear_to_front = []
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000008?line=2'>3</a> for i in filtered_ngsim_I.index:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000008?line=3'>4</a>     space=filtered_ngsim_I['Space_Headway'][i]  - filtered_vClass_I['v_length'][filtered_vClass_I['Vehicle_ID']== filtered_ngsim_I['Preceding'][i]].mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000008?line=4'>5</a>     space_headway_rear_to_front.append(space)
#       <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000008?line=5'>6</a>     if i%500000==0:
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\series.py:982, in Series.__getitem__(self, key)
#     980     key = check_bool_indexer(self.index, key)
#     981     key = np.asarray(key, dtype=bool)
# --> 982     return self._get_values(key)
#     984 return self._get_with(key)
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\series.py:1044, in Series._get_values(self, indexer)
#    1042 def _get_values(self, indexer):
#    1043     try:
# -> 1044         new_mgr = self._mgr.getitem_mgr(indexer)
#    1045         return self._constructor(new_mgr).__finalize__(self)
#    1046     except ValueError:
#    1047         # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1048         #  see tests.series.timeseries.test_mpl_compat_hack
#    1049         # the asarray is needed to avoid returning a 2D DatetimeArray
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\internals\managers.py:1809, in SingleBlockManager.getitem_mgr(self, indexer)
#    1806 def getitem_mgr(self, indexer) -> SingleBlockManager:
#    1807     # similar to get_slice, but not restricted to slice indexer
#    1808     blk = self._block
# -> 1809     array = blk._slice(indexer)
#    1810     if array.ndim > 1:
#    1811         # This will be caught by Series._get_values
#    1812         raise ValueError("dimension-expanding indexing not allowed")
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\internals\blocks.py:313, in Block._slice(self, slicer)
#     310 def _slice(self, slicer) -> ArrayLike:
#     311     """return a slice of my values"""
# --> 313     return self.values[slicer]
#
# KeyboardInterrupt:

# %%
'''
space_headway_rear_to_front = []

for i in filtered_ngsim_U.index:
    space = filtered_ngsim_U['Space_Headway'][i]  - filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== filtered_ngsim_U['Preceding'][i]].mean()
    space_headway_rear_to_front.append(space)
    if i%500000==0:
        print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")
        

filtered_ngsim_U['Rear_to_Front_Space_Headway'] = space_headway_rear_to_front
'''
# Out:
# row count0.00 processed
# row count500.00k processed
# row count2.50M processed
# row count3.50M processed
# row count4.00M processed
# row count5.00M processed
# row count5.50M processed
# row count6.00M processed
# row count6.50M processed
# row count7.50M processed
# row count8.00M processed
# row count8.50M processed

# %%
filtered_ngsim_U['Vehicle_combination']= filtered_ngsim_U['Preceding_Vehicle_Class'] + '-' + filtered_ngsim_U['v_Class_Name']
filtered_ngsim_I['Vehicle_combination']= filtered_ngsim_I['Preceding_Vehicle_Class'] + '-' + filtered_ngsim_I['v_Class_Name']

# %%
filtered_ngsim= pd.concat([filtered_ngsim_U , filtered_ngsim_I])

# %%
print(filtered_ngsim_U.shape[0])
print(filtered_ngsim_I.shape[0])
print(filtered_ngsim.shape[0])
# Out:
# 4098933
# 4555939
# 8654872

# %%
stringpath= str(p)[0:str(p).rfind('\\')] + '\\data'
ngsimfilteredfile=stringpath + '\\' + 'Cleaned_NGSIM_Data_Part_1.csv'
filtered_ngsim.to_csv(ngsimfilteredfile, index = False)

# %%
#this is converted to feet data
filtered_vClass_U['v_length'][filtered_vClass_U['Vehicle_ID']== 500 ].mean()
# Out:
# 5.384799999999999

# %%
filtered_ngsim_U[:2]
# Out:
#    Vehicle_ID    Global_Time  Local_X   Local_Y     Global_X     Global_Y  \
# 0         515  1118848075000   30.034   188.062  6451203.729  1873252.549
# 3        2127  1118847624800   19.632  1775.614  6452425.122  1872172.475
#
#    v_length  v_Class      v_Vel    v_Acc  Preceding  Space_Headway  \
# 0    3.9624        2   7.104888  0.62484        500      36.301680
# 3    4.1148        2  11.436096  3.41376       2124      14.910816
#
#    Time_Headway Location  Relative_Time  Preceding_Vehicle_Class  \
# 0          5.11   us-101  1117685055901                      NaN
# 3          1.30   us-101  1117684605701                      NaN
#
#    Rear_to_Front_Space_Headway  Follower_Minus_Preceding_Velocity_diff  \
# 0                          NaN                                     NaN
# 3                          NaN                                     NaN
#
#   v_Class_Name
# 0          Car
# 3          Car

# %%
print(filtered_ngsim_U['v_Vel'][((filtered_ngsim_U['Vehicle_ID'] == 500 ) & (filtered_ngsim_U['Relative_Time'] == 1117685055901 )) ])

print(filtered_ngsim_U['v_Vel'][((filtered_ngsim_U['Vehicle_ID'] == 515 ) & (filtered_ngsim_U['Relative_Time'] == 1117685055901 )) ])
# Out:
# 7061760    8.772144
# Name: v_Vel, dtype: float64
# 0    7.104888
# Name: v_Vel, dtype: float64

# %%
filtered_ngsim_U['Relative_Time'].dtype
# Out:
# dtype('int64')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts\Part-1_Data-Cleanup.ipynb Cell 21' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/StudentAccount/Python/Capstone/gitcodelocation/DataDrivenCarFollowing/datadrivencarfollowing-v1/scripts/Part-1_Data-Cleanup.ipynb#ch0000023?line=0'>1</a> filtered_ngsim_U.set_index(['Vehicle_ID', 'Preceding','Relative_Time'], append=True,inplace=True)
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\StudentAccount\anaconda\envs\Project\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['Vehicle_ID', 'Relative_Time'] are in the columns"

# %%
filtered_ngsim_U
# Out:
#                                                             Global_Time  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901  1118848075000
# 7       744        NaN                     1117685162101  1118848181200
# 15      496        NaN                     1117685099501  1118848118600
# 17      946        NaN                     1117685233301  1118848252400
# 28      5          NaN                     1117684841001  1118847860100
# ...                                                                 ...
# 8704785 582        NaN                     1117684102401  1118847121500
# 8704787 690        NaN                     1117684133501  1118847152600
# 8704790 347        NaN                     1117685038201  1118848057300
# 8704793 448        NaN                     1117685991101  1118849010200
# 8704797 601        NaN                     1117684146901  1118847166000
#
#                                                           Local_X   Local_Y  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901   30.034   188.062
# 7       744        NaN                     1117685162101   28.878   490.086
# 15      496        NaN                     1117685099501   52.141  1656.454
# 17      946        NaN                     1117685233301    5.373   365.819
# 28      5          NaN                     1117684841001    4.948   149.178
# ...                                                           ...       ...
# 8704785 582        NaN                     1117684102401   27.986   210.580
# 8704787 690        NaN                     1117684133501   40.584   298.509
# 8704790 347        NaN                     1117685038201   41.208  1802.654
# 8704793 448        NaN                     1117685991101   41.050   866.711
# 8704797 601        NaN                     1117684146901   54.735  1988.482
#
#                                                              Global_X  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901  6451203.729
# 7       744        NaN                     1117685162101  6451422.353
# 15      496        NaN                     1117685099501  6452284.002
# 17      946        NaN                     1117685233301  6451347.228
# 28      5          NaN                     1117684841001  6451195.587
# ...                                                               ...
# 8704785 582        NaN                     1117684102401  6451248.662
# 8704787 690        NaN                     1117684133501  6451303.292
# 8704790 347        NaN                     1117685038201  6452401.087
# 8704793 448        NaN                     1117685991101  6451700.402
# 8704797 601        NaN                     1117684146901  6452564.992
#
#                                                              Global_Y  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901  1873252.549
# 7       744        NaN                     1117685162101  1873041.018
# 15      496        NaN                     1117685099501  1872253.037
# 17      946        NaN                     1117685233301  1873143.047
# 28      5          NaN                     1117684841001  1873298.132
# ...                                                               ...
# 8704785 582        NaN                     1117684102401  1873208.150
# 8704787 690        NaN                     1117684133501  1873136.542
# 8704790 347        NaN                     1117685038201  1872164.685
# 8704793 448        NaN                     1117685991101  1872777.534
# 8704797 601        NaN                     1117684146901  1872006.298
#
#                                                           v_length  v_Class  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901   3.96240        2
# 7       744        NaN                     1117685162101   4.57200        2
# 15      496        NaN                     1117685099501   4.57200        2
# 17      946        NaN                     1117685233301   3.96240        2
# 28      5          NaN                     1117684841001   3.96240        2
# ...                                                            ...      ...
# 8704785 582        NaN                     1117684102401  23.19528        3
# 8704787 690        NaN                     1117684133501   5.02920        2
# 8704790 347        NaN                     1117685038201   4.41960        2
# 8704793 448        NaN                     1117685991101   6.09600        2
# 8704797 601        NaN                     1117684146901   5.48640        2
#
#                                                               v_Vel     v_Acc  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901   7.104888  0.624840
# 7       744        NaN                     1117685162101   7.479792 -0.012192
# 15      496        NaN                     1117685099501   9.933432 -2.112264
# 17      946        NaN                     1117685233301   6.909816  0.000000
# 28      5          NaN                     1117684841001   0.000000  0.000000
# ...                                                             ...       ...
# 8704785 582        NaN                     1117684102401  10.229088  3.413760
# 8704787 690        NaN                     1117684133501  11.780520  1.036320
# 8704790 347        NaN                     1117685038201   7.620000  0.000000
# 8704793 448        NaN                     1117685991101   9.040368 -1.274064
# 8704797 601        NaN                     1117684146901  17.614392  0.310896
#
#                                                           Preceding  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901        500
# 7       744        NaN                     1117685162101        740
# 15      496        NaN                     1117685099501        510
# 17      946        NaN                     1117685233301        936
# 28      5          NaN                     1117684841001          0
# ...                                                             ...
# 8704785 582        NaN                     1117684102401        561
# 8704787 690        NaN                     1117684133501        680
# 8704790 347        NaN                     1117685038201        338
# 8704793 448        NaN                     1117685991101        445
# 8704797 601        NaN                     1117684146901        593
#
#                                                           Space_Headway  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901      36.301680
# 7       744        NaN                     1117685162101      11.521440
# 15      496        NaN                     1117685099501      20.790408
# 17      946        NaN                     1117685233301      18.574512
# 28      5          NaN                     1117684841001       0.000000
# ...                                                                 ...
# 8704785 582        NaN                     1117684102401      31.476696
# 8704787 690        NaN                     1117684133501      27.535632
# 8704790 347        NaN                     1117685038201      25.383744
# 8704793 448        NaN                     1117685991101      15.057120
# 8704797 601        NaN                     1117684146901      35.524440
#
#                                                           Time_Headway  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901          5.11
# 7       744        NaN                     1117685162101          1.54
# 15      496        NaN                     1117685099501          2.09
# 17      946        NaN                     1117685233301          2.69
# 28      5          NaN                     1117684841001          0.00
# ...                                                                ...
# 8704785 582        NaN                     1117684102401          3.08
# 8704787 690        NaN                     1117684133501          2.34
# 8704790 347        NaN                     1117685038201          3.33
# 8704793 448        NaN                     1117685991101          1.67
# 8704797 601        NaN                     1117684146901          2.02
#
#                                                          Location  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901   us-101
# 7       744        NaN                     1117685162101   us-101
# 15      496        NaN                     1117685099501   us-101
# 17      946        NaN                     1117685233301   us-101
# 28      5          NaN                     1117684841001   us-101
# ...                                                           ...
# 8704785 582        NaN                     1117684102401   us-101
# 8704787 690        NaN                     1117684133501   us-101
# 8704790 347        NaN                     1117685038201   us-101
# 8704793 448        NaN                     1117685991101   us-101
# 8704797 601        NaN                     1117684146901   us-101
#
#                                                           Rear_to_Front_Space_Headway  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901                          NaN
# 7       744        NaN                     1117685162101                          NaN
# 15      496        NaN                     1117685099501                          NaN
# 17      946        NaN                     1117685233301                          NaN
# 28      5          NaN                     1117684841001                          NaN
# ...                                                                               ...
# 8704785 582        NaN                     1117684102401                          NaN
# 8704787 690        NaN                     1117684133501                          NaN
# 8704790 347        NaN                     1117685038201                          NaN
# 8704793 448        NaN                     1117685991101                          NaN
# 8704797 601        NaN                     1117684146901                          NaN
#
#                                                           Follower_Minus_Preceding_Velocity_diff  \
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901                                     NaN
# 7       744        NaN                     1117685162101                                     NaN
# 15      496        NaN                     1117685099501                                     NaN
# 17      946        NaN                     1117685233301                                     NaN
# 28      5          NaN                     1117684841001                                     NaN
# ...                                                                                          ...
# 8704785 582        NaN                     1117684102401                                     NaN
# 8704787 690        NaN                     1117684133501                                     NaN
# 8704790 347        NaN                     1117685038201                                     NaN
# 8704793 448        NaN                     1117685991101                                     NaN
# 8704797 601        NaN                     1117684146901                                     NaN
#
#                                                            v_Class_Name
#         Vehicle_ID Preceding_Vehicle_Class Relative_Time
# 0       515        NaN                     1117685055901            Car
# 7       744        NaN                     1117685162101            Car
# 15      496        NaN                     1117685099501            Car
# 17      946        NaN                     1117685233301            Car
# 28      5          NaN                     1117684841001            Car
# ...                                                                 ...
# 8704785 582        NaN                     1117684102401  Heavy Vehicle
# 8704787 690        NaN                     1117684133501            Car
# 8704790 347        NaN                     1117685038201            Car
# 8704793 448        NaN                     1117685991101            Car
# 8704797 601        NaN                     1117684146901            Car
#
# [1645876 rows x 16 columns]

# %%
# Out:
# Int64Index([515, 744, 496, 946,   5, 686, 709, 485, 182, 143,
#             ...
#             406, 711, 447, 375, 427, 582, 690, 347, 448, 601],
#            dtype='int64', name='Vehicle_ID', length=1645876)

# %%
filtered_ngsim_U[((filtered_ngsim_U['Space_Headway'] == 0 ) & (filtered_ngsim_U.index.get_level_values("Preceding") > 0 )) ]
#filtered_ngsim_U[((filtered_ngsim_U['Space_Headway'] == 0 ) & (filtered_ngsim_U['Preceding'] > 0 )) ]
# Out:
#                                              Global_Time  Local_X   Local_Y  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401  1118847948500   12.942  1420.624
# 107058 806        814       1117685210701  1118848229800    6.699   796.216
# 452347 366        370       1117685952801  1118848971900   12.613   835.132
#
#                                               Global_X     Global_Y  v_length  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401  6452132.084  1872437.889    2.5908
# 107058 806        814       1117685210701  6451666.005  1872853.511    4.4196
# 452347 366        370       1117685952801  6451695.487  1872819.732    2.1336
#
#                                            v_Class      v_Vel     v_Acc  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401        1  17.373600 -0.064008
# 107058 806        814       1117685210701        2   2.795016  0.000000
# 452347 366        370       1117685952801        1   8.695944  1.816608
#
#                                            Space_Headway  Time_Headway  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401            0.0           0.0
# 107058 806        814       1117685210701            0.0           0.0
# 452347 366        370       1117685952801            0.0           0.0
#
#                                           Location  Preceding_Vehicle_Class  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401   us-101                      NaN
# 107058 806        814       1117685210701   us-101                      NaN
# 452347 366        370       1117685952801   us-101                      NaN
#
#                                            Rear_to_Front_Space_Headway  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401                          NaN
# 107058 806        814       1117685210701                          NaN
# 452347 366        370       1117685952801                          NaN
#
#                                            Follower_Minus_Preceding_Velocity_diff  \
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401                                     NaN
# 107058 806        814       1117685210701                                     NaN
# 452347 366        370       1117685952801                                     NaN
#
#                                           v_Class_Name
# id     Vehicle_ID Preceding Relative_Time
# 76361  99         92        1117684929401   Motorcycle
# 107058 806        814       1117685210701          Car
# 452347 366        370       1117685952801   Motorcycle

# %%
filtered_ngsim_U.index.get_level_values("Preceding")
# Out:
# Int64Index([500, 740, 510, 936,   0, 680,   0, 479, 170, 135,
#             ...
#             401, 704, 442, 384, 422, 561, 680, 338, 445, 593],
#            dtype='int64', name='Preceding', length=1645876)

# %%
filtered_ngsim_U.xs((filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Relative_Time")[0],filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Preceding").values[0]),level=("Relative_Time",'Vehicle_ID')).index.get_level_values('id').values[0]
# Out:
# 7061760

# %%
velocity_diff=[]

for i in filtered_ngsim_U.index.get_level_values(0):
    #print(i)
    if i%100==0:
        print(f"row count{millify(i, precision=2, drop_nulls=False)} processed")
    preceding_corresponding_id=filtered_ngsim_U.xs((filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Relative_Time")[0],filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Preceding").values[0]),level=("Relative_Time",'Vehicle_ID')).index.get_level_values('id').values[0] 
    preceding_corresponding_id
    #print(f"velocity previous :{ filtered_ngsim_U['v_Vel'][(filtered_ngsim_U.index.get_level_values('id') == preceding_corresponding_id ) ].values}")
    #print(f"velocity current : { filtered_ngsim_U['v_Vel'][(filtered_ngsim_U.index.get_level_values('id') == i ) ].values}")
    velocity = filtered_ngsim_U['v_Vel'][(filtered_ngsim_U.index.get_level_values('id') == i ) ].values - filtered_ngsim_U['v_Vel'][(filtered_ngsim_U.index.get_level_values('id') == preceding_corresponding_id ) ].values
    #if i >= 0:
    #    break    
    velocity_diff.append(velocity)
# Out:
# row count0.00 processed

# %%
filtered_ngsim_U.xs((0,500,515),level=("id","Preceding",'Vehicle_ID'),"v_Vel")
# Out:
#   Input In [165]
#     filtered_ngsim_U.xs((0,500,515),level=("id","Preceding",'Vehicle_ID'),"v_Vel")
#                                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
filtered_ngsim_U["v_Class"][(filtered_ngsim_U.index.get_level_values("Vehicle_ID") == 515 ) & (filtered_ngsim_U.index.get_level_values("Preceding") == 500 ) &(filtered_ngsim_U.index.get_level_values("id") == 0 ) ]
# Out:
# id  Vehicle_ID  Preceding  Relative_Time
# 0   515         500        1117685055901    2
# Name: v_Class, dtype: int64

# %%
filtered_ngsim_U["v_Class"][(filtered_ngsim_U.index.get_level_values("Vehicle_ID") == 515 ) & (filtered_ngsim_U.index.get_level_values("Preceding") == 500 ) &(filtered_ngsim_U.index.get_level_values("id") == 0 ) ].index
# Out:
# MultiIndex([(0, 515, 500, 1117685055901)],
#            names=['id', 'Vehicle_ID', 'Preceding', 'Relative_Time'])

# %%
filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("Vehicle_ID") == 515 ) & (filtered_ngsim_U.index.get_level_values("Preceding") == 500 ) &(filtered_ngsim_U.index.get_level_values("id") == 0 ) ].index.get_level_values("Relative_Time")
# Out:
# Int64Index([0], dtype='int64', name='id')

# %%
filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Relative_Time")
# Out:
# Int64Index([1117685055901], dtype='int64', name='Relative_Time')

# %%
filtered_ngsim_U[(filtered_ngsim_U.index.get_level_values("id") == 0 )].index.get_level_values("Preceding").values[0]
# Out:
# 500

# %%
filtered_ngsim_U["v_Vel"][(filtered_ngsim_U.index.get_level_values("id") == 515 ) ]
# Out:
# id   Vehicle_ID  Preceding  Relative_Time
# 515  21          8          1117683986301    13.267944
# Name: v_Vel, dtype: float64
