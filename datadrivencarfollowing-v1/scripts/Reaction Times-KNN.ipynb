# %% [markdown]
# Importing required libraries to predict acceleration using random forest, calculate RMSE (RootMeanSquaredError), and create plots to compare predicted and actual acceleration

# %%
import pandas as pd
import numpy as np

#import src
import FileProcessing
import ModelClass

# %% [markdown]
# Loading the cleaned ngsim data using pandas

# %%
fileProcessing=FileProcessing.FileProcessing()

# %%
model_obj=ModelClass.ModelClass()
file=FileProcessing.FileProcessing()

# %%
file_name='Cleaned_NGSIM_Data'
ngsim=fileProcessing.read_input(file_name)
# Out:
# original File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Data File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data

# %%
delta_time=0.1
ngsim_0_1, train_df_0_1, val_df_0_1, test_df_0_1, X_train_0_1, y_train_0_1, X_val_0_1, y_val_0_1, X_test_0_1, y_test_0_1,predicted_data_0_1,model_0_1= model_obj.fit_and_run_KNN(ngsim, delta_time)

file.export_file(ngsim_0_1, 'knn_ngsim_0_1')
file.export_file(train_df_0_1, 'knn_train_df_0_1')
file.export_file(val_df_0_1, 'knn_val_df_0_1')
file.export_file(test_df_0_1, 'knn_test_df_0_1')
file.export_file(X_train_0_1, 'knn_X_train_0_1')
file.export_file(y_train_0_1, 'knn_y_train_0_1')

file.export_file(X_val_0_1, 'knn_X_val_0_1')
file.export_file(y_val_0_1, 'knn_y_val_0_1')
file.export_file(X_test_0_1, 'knn_X_test_0_1')
file.export_file(y_test_0_1, 'knn_y_test_0_1')
file.export_file(predicted_data_0_1, 'knn_predicted_data_0_1')
# Out:
# Prediction being done on :163-176
# True

# %%
#define the timeframe for the run
delta_time=0.5
ngsim_0_5, train_df_0_5, val_df_0_5, test_df_0_5, X_train_0_5, y_train_0_5, X_val_0_5, y_val_0_5, X_test_0_5, y_test_0_5,predicted_data_0_5,model_0_5 = model_obj.fit_and_run_KNN(ngsim, delta_time)

file.export_file(ngsim_0_5, 'knn_ngsim_0_5')
file.export_file(train_df_0_5, 'knn_train_df_0_5')
file.export_file(val_df_0_5, 'knn_val_df_0_5')
file.export_file(test_df_0_5, 'knn_test_df_0_5')
file.export_file(X_train_0_5, 'knn_X_train_0_5')
file.export_file(y_train_0_5, 'knn_y_train_0_5')

file.export_file(X_val_0_5, 'knn_X_val_0_5')
file.export_file(y_val_0_5, 'knn_y_val_0_5')
file.export_file(X_test_0_5, 'knn_X_test_0_5')
file.export_file(y_test_0_5, 'knn_y_test_0_5')
file.export_file(predicted_data_0_5, 'knn_predicted_data_0_5')
# Out:
# Prediction being done on :271-280
# True

# %%
delta_time=1
ngsim_1, train_df_1, val_df_1, test_df_1, X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1,predicted_data_1,model_1= model_obj.fit_and_run_KNN(ngsim, delta_time)

file.export_file(ngsim_1, 'knn_ngsim_1')
file.export_file(train_df_1, 'knn_train_df_1')
file.export_file(val_df_1, 'knn_val_df_1')
file.export_file(test_df_1, 'knn_test_df_1')
file.export_file(X_train_1, 'knn_X_train_1')
file.export_file(y_train_1, 'knn_y_train_1')

file.export_file(X_val_1, 'knn_X_val_1')
file.export_file(y_val_1, 'knn_y_val_1')
file.export_file(X_test_1, 'knn_X_test_1')
file.export_file(y_test_1, 'knn_y_test_1')
file.export_file(predicted_data_1, 'knn_predicted_data_1')
# Out:
# Prediction being done on :203-212
# True

# %%
delta_time=2
ngsim_2, train_df_2, val_df_2, test_df_2, X_train_2, y_train_2, X_val_2, y_val_2, X_test_2, y_test_2,predicted_data_2,model_2= model_obj.fit_and_run_KNN(ngsim, delta_time)


file.export_file(ngsim_2, 'knn_ngsim_2')
file.export_file(train_df_2, 'knn_train_df_2')
file.export_file(val_df_2, 'knn_val_df_2')
file.export_file(test_df_2, 'knn_test_df_2')
file.export_file(X_train_2, 'knn_X_train_2')
file.export_file(y_train_2, 'knn_y_train_2')

file.export_file(X_val_2, 'knn_X_val_2')
file.export_file(y_val_2, 'knn_y_val_2')
file.export_file(X_test_2, 'knn_X_test_2')
file.export_file(y_test_2, 'knn_y_test_2')
file.export_file(predicted_data_2, 'knn_predicted_data_2')
# Out:
# Prediction being done on :94-105
# True

# %%
delta_time=5
ngsim_5, train_df_5, val_df_5, test_df_5, X_train_5, y_train_5, X_val_5, y_val_5, X_test_5, y_test_5,predicted_data_5,model_5= model_obj.fit_and_run_KNN(ngsim, delta_time)


file.export_file(ngsim_5, 'knn_ngsim_5')
file.export_file(train_df_5, 'knn_train_df_5')
file.export_file(val_df_5, 'knn_val_df_5')
file.export_file(test_df_5, 'knn_test_df_5')
file.export_file(X_train_5, 'knn_X_train_5')
file.export_file(y_train_5, 'knn_y_train_5')

file.export_file(X_val_5, 'knn_X_val_5')
file.export_file(y_val_5, 'knn_y_val_5')
file.export_file(X_test_5, 'knn_X_test_5')
file.export_file(y_test_5, 'knn_y_test_5')
file.export_file(predicted_data_5, 'knn_predicted_data_5')
# Out:
# Prediction being done on :134-137
# True

# %%
delta_time=10
ngsim_10, train_df_10, val_df_10, test_df_10, X_train_10, y_train_10, X_val_10, y_val_10, X_test_10, y_test_10,predicted_data_10,model_10= model_obj.fit_and_run_KNN(ngsim, delta_time)

file.export_file(ngsim_10, 'knn_ngsim_10')
file.export_file(train_df_10, 'knn_train_df_10')
file.export_file(val_df_10, 'knn_val_df_10')
file.export_file(test_df_10, 'knn_test_df_10')
file.export_file(X_train_10, 'knn_X_train_10')
file.export_file(y_train_10, 'knn_y_train_10')

file.export_file(X_val_10, 'knn_X_val_10')
file.export_file(y_val_10, 'knn_y_val_10')
file.export_file(X_test_10, 'knn_X_test_10')
file.export_file(y_test_10, 'knn_y_test_10')
file.export_file(predicted_data_10, 'knn_predicted_data_10')
# Out:
# Prediction being done on :206-213
# True
