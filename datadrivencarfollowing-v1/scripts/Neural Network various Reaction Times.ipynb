# %% [markdown]
# Importing required libraries to predict acceleration using random forest, calculate RMSE (RootMeanSquaredError), and create plots to compare predicted and actual acceleration

# %%
import pandas as pd
import numpy as np

#import src
import FileProcessing
import ModelClass

# %% [markdown]
# Loading the cleaned ngsim data using pandas

# %%
fileProcessing=FileProcessing.FileProcessing()

# %%
model_obj=ModelClass.ModelClass()
file=FileProcessing.FileProcessing()

# %%
file_name='less than1 second removed-Cleaned_NGSIM_Data'
ngsim=fileProcessing.read_input(file_name)
# Out:
# original File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Data File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data

# %%
#define the timeframe for the run
time_frame=0.5
ngsim_0_5, train_df_0_5, val_df_0_5, test_df_0_5, X_train_0_5, y_train_0_5, X_val_0_5, y_val_0_5, X_test_0_5, y_test_0_5,predicted_data_0_5,model_0_5 = model_obj.fit_and_run_neural(ngsim, time_frame)

file.export_file(ngsim_0_5, '5 Seconds_Removed-ngsim_0_5')
file.export_file(train_df_0_5, '5 Seconds_Removed-train_df_0_5')
file.export_file(val_df_0_5, '5 Seconds_Removed-val_df_0_5')
file.export_file(test_df_0_5, '5 Seconds_Removed-test_df_0_5')
file.export_file(X_train_0_5, '5 Seconds_Removed-X_train_0_5')
file.export_file(y_train_0_5, '5 Seconds_Removed-y_train_0_5')

file.export_file(X_val_0_5, '5 Seconds_Removed-X_val_0_5')
file.export_file(y_val_0_5, '5 Seconds_Removed-y_val_0_5')
file.export_file(X_test_0_5, '5 Seconds_Removed-X_test_0_5')
file.export_file(y_test_0_5, '5 Seconds_Removed-y_test_0_5')
file.export_file(predicted_data_0_5, '5 Seconds_Removed-predicted_data_0_5')
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 6, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 6, 16)             528
# _________________________________________________________________
# Block1_Pool (MaxPooling1D)   (None, 3, 16)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 3, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 3, 32)             2080
# ...

# %%
time_frame=1
ngsim_1, train_df_1, val_df_1, test_df_1, X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1,predicted_data_1,model_1= model_obj.fit_and_run_neural(ngsim, time_frame)

file.export_file(ngsim_1, '5 Seconds_Removed-ngsim_1')
file.export_file(train_df_1, '5 Seconds_Removed-train_df_1')
file.export_file(val_df_1, '5 Seconds_Removed-val_df_1')
file.export_file(test_df_1, '5 Seconds_Removed-test_df_1')
file.export_file(X_train_1, '5 Seconds_Removed-X_train_1')
file.export_file(y_train_1, '5 Seconds_Removed-y_train_1')

file.export_file(X_val_1, '5 Seconds_Removed-X_val_1')
file.export_file(y_val_1, '5 Seconds_Removed-y_val_1')
file.export_file(X_test_1, '5 Seconds_Removed-X_test_1')
file.export_file(y_test_1, '5 Seconds_Removed-y_test_1')
file.export_file(predicted_data_1, '5 Seconds_Removed-predicted_data_1')
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 6, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 6, 16)             528
# _________________________________________________________________
# Block1_Pool (MaxPooling1D)   (None, 3, 16)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 3, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 3, 32)             2080
# ...

# %%
time_frame=2
ngsim_2, train_df_2, val_df_2, test_df_2, X_train_2, y_train_2, X_val_2, y_val_2, X_test_2, y_test_2,predicted_data_2,model_2= model_obj.fit_and_run_neural(ngsim, time_frame)


file.export_file(ngsim_2, '5 Seconds_Removed-ngsim_2')
file.export_file(train_df_2, '5 Seconds_Removed-train_df_2')
file.export_file(val_df_2, '5 Seconds_Removed-val_df_2')
file.export_file(test_df_2, '5 Seconds_Removed-test_df_2')
file.export_file(X_train_2, '5 Seconds_Removed-X_train_2')
file.export_file(y_train_2, '5 Seconds_Removed-y_train_2')

file.export_file(X_val_2, '5 Seconds_Removed-X_val_2')
file.export_file(y_val_2, '5 Seconds_Removed-y_val_2')
file.export_file(X_test_2, '5 Seconds_Removed-X_test_2')
file.export_file(y_test_2, '5 Seconds_Removed-y_test_2')
file.export_file(predicted_data_2, '5 Seconds_Removed-predicted_data_2')
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 6, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 6, 16)             528
# _________________________________________________________________
# Block1_Pool (MaxPooling1D)   (None, 3, 16)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 3, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 3, 32)             2080
# ...

# %%
time_frame=5
ngsim_5, train_df_5, val_df_5, test_df_5, X_train_5, y_train_5, X_val_5, y_val_5, X_test_5, y_test_5,predicted_data_5,model_5= model_obj.fit_and_run_neural(ngsim, time_frame)


file.export_file(ngsim_5, '5 Seconds_Removed-ngsim_5')
file.export_file(train_df_5, '5 Seconds_Removed-train_df_5')
file.export_file(val_df_5, '5 Seconds_Removed-val_df_5')
file.export_file(test_df_5, '5 Seconds_Removed-test_df_5')
file.export_file(X_train_5, '5 Seconds_Removed-X_train_5')
file.export_file(y_train_5, '5 Seconds_Removed-y_train_5')

file.export_file(X_val_5, '5 Seconds_Removed-X_val_5')
file.export_file(y_val_5, '5 Seconds_Removed-y_val_5')
file.export_file(X_test_5, '5 Seconds_Removed-X_test_5')
file.export_file(y_test_5, '5 Seconds_Removed-y_test_5')
file.export_file(predicted_data_5, '5 Seconds_Removed-predicted_data_5')
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 6, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 6, 16)             528
# _________________________________________________________________
# Block1_Pool (MaxPooling1D)   (None, 3, 16)             0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 3, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 3, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 3, 32)             2080
# ...

# %%
time_frame=10
ngsim_10, train_df_10, val_df_10, test_df_10, X_train_10, y_train_10, X_val_10, y_val_10, X_test_10, y_test_10,predicted_data_10,model_10= model_obj.fit_and_run_neural(ngsim, time_frame)



file.export_file(ngsim_10, '5 Seconds_Removed-ngsim_10')
file.export_file(train_df_10, '5 Seconds_Removed-train_df_10')
file.export_file(val_df_10, '5 Seconds_Removed-val_df_10')
file.export_file(test_df_10, '5 Seconds_Removed-test_df_10')
file.export_file(X_train_10, '5 Seconds_Removed-X_train_10')
file.export_file(y_train_10, '5 Seconds_Removed-y_train_10')

file.export_file(X_val_10, '5 Seconds_Removed-X_val_10')
file.export_file(y_val_10, '5 Seconds_Removed-y_val_10')
file.export_file(X_test_10, '5 Seconds_Removed-X_test_10')
file.export_file(y_test_10, '5 Seconds_Removed-y_test_10')
file.export_file(predicted_data_10, '5 Seconds_Removed-predicted_data_10')
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 6, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 6, 16)             528
# _________________________________________________________________
# Block1_Pool (MaxPooling1D)   (None, 3, 16)             0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 3, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 3, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 3, 32)             2080
# ...
